# %%
# Let's recreate the visualization from Chapter 2 of Claus Wilke's book
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

BF = pd.read_csv('BigFoot.csv')
BF
# Out:
#       Year Season            State
# 0   2010.0  Summer         Alabama
# 1   1992.0    Fall          Alaska
# 2   1974.0    Fall    Rhode Island
# 3   1973.0  Summer    Pennsylvania
# 4   1984.0  Spring          Oregon
# 5   1973.0    Fall        Oklahoma
# 6   1971.0  Summer            Ohio
# 7   2010.0    Fall        New York
# 8   1970.0    Fall          Nevada
# 9      NaN     NaN             NaN
# 10  2000.0    Fall      New Jersey
# 11  2016.0  Summer   New Hampshire
# 12  2018.0  Spring        Nebraska
# 13  1962.0  Spring    North Dakota
# 14  1988.0  Spring  North Carolina
# 15  1971.0  Summer         Montana
# 16  1988.0  Winter         Montana
# 17  2007.0  Summer         Montana
# 18  2011.0  Summer  North Carolina
# 19  1987.0  Summer      New Jersey
# 20  2007.0  Winter      New Jersey
# 21  1981.0  Spring      New Jersey
# 22  1977.0  Summer      New Jersey
# 23  2000.0  Spring      New Mexico
# 24  2006.0    Fall      New Mexico
# 25  2009.0  Summer      New Mexico
# ...

# %%
Summerslice = BF.loc[BF['Season'].str.contains('Summer')]
 
Summerslice
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Documents\SPRING 2023\Stat Mech\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\Documents\SPRING 2023\Stat Mech\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Documents\SPRING 2023\Stat Mech\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Season'
#
# The above exception was the direct cause of the following exception:
#
# ...
